# %%
import pandas as pd

print("Proyecto eCommerce KPI Analysis iniciado")
# Out:
# Proyecto eCommerce KPI Analysis iniciado

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\pdana\OneDrive\Documentos\GitHub\ecommerce-sales-analysis\venv\Scripts\python.exe
